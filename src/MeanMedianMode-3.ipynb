# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# 26994.405794750528

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# 27020.34786967931

# %% [markdown]
# Now we'll add Jeff Bezos into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# 27022.052578223593

# %%
np.mean(incomes)
# Out:
# 126981.70762398813

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([63, 82, 79, 54, 18, 21, 57, 77, 85, 47, 48, 44, 82, 46, 44, 57, 23,
#        25, 73, 83, 41, 23, 85, 81, 36, 20, 66, 51, 45, 35, 52, 79, 45, 88,
#        62, 43, 40, 45, 37, 19, 76, 28, 26, 67, 74, 36, 22, 80, 70, 21, 74,
#        31, 30, 50, 25, 48, 63, 63, 21, 86, 32, 35, 83, 75, 86, 75, 31, 53,
#        87, 68, 26, 66, 41, 86, 20, 20, 24, 58, 82, 30, 25, 38, 70, 72, 63,
#        61, 40, 32, 33, 73, 42, 27, 74, 83, 83, 39, 40, 65, 31, 75, 74, 50,
#        48, 35, 59, 57, 36, 25, 39, 88, 74, 43, 46, 54, 45, 69, 37, 24, 67,
#        68, 44, 81, 59, 27, 63, 88, 52, 46, 30, 45, 48, 58, 69, 46, 31, 79,
#        41, 48, 70, 63, 63, 43, 62, 53, 39, 34, 73, 71, 41, 76, 80, 70, 60,
#        47, 23, 30, 43, 51, 79, 39, 51, 71, 71, 57, 56, 23, 69, 45, 27, 77,
#        19, 75, 46, 63, 74, 71, 41, 28, 19, 20, 83, 23, 49, 26, 23, 62, 67,
#        45, 53, 26, 64, 35, 82, 30, 43, 75, 39, 52, 50, 47, 59, 28, 62, 38,
#        25, 67, 64, 27, 57, 21, 19, 51, 81, 75, 40, 31, 46, 89, 51, 79, 65,
#        43, 44, 69, 42, 62, 29, 57, 22, 74, 18, 69, 41, 89, 86, 24, 82, 41,
#        21, 86, 66, 21, 58, 64, 66, 52, 30, 25, 35, 32, 36, 67, 61, 76, 79,
#        87, 86, 59, 41, 85, 45, 89, 88, 44, 51, 61, 82, 81, 19, 67, 34, 71,
#        76, 85, 20, 75, 46, 31, 65, 86, 38, 48, 24, 46, 81, 42, 75, 68, 43,
#        49, 35, 51, 21, 65, 41, 62, 84, 24, 27, 66, 57, 87, 75, 79, 80, 22,
#        19, 75, 21, 43, 78, 23, 89, 42, 30, 33, 77, 40, 76, 41, 58, 83, 41,
#        53, 25, 40, 85, 53, 69, 71, 42, 54, 52, 73, 40, 26, 77, 79, 50, 43,
#        25, 42, 62, 26, 75, 43, 74, 20, 38, 31, 18, 64, 67, 23, 85, 40, 23,
#        86, 65, 68, 78, 86, 63, 75, 36, 38, 23, 86, 20, 29, 67, 74, 67, 30,
#        87, 58, 76, 54, 24, 55, 82, 43, 26, 88, 74, 83, 27, 34, 60, 25, 74,
#        22, 82, 34, 66, 50, 25, 77, 75, 34, 41, 21, 56, 38, 70, 43, 18, 23,
#        31, 43, 58, 61, 80, 34, 78, 23, 26, 55, 62, 44, 36, 39, 75, 29, 65,
#        76, 62, 68, 61, 50, 81, 47, 89, 72, 61, 58, 25, 48, 47, 28, 26, 51,
#        63, 19, 81, 72, 72, 31, 47, 50, 37, 20, 37, 30, 63, 35, 53, 69, 21,
#        84, 85, 89, 75, 54, 75, 26, 79, 22, 43, 52, 46, 87, 45, 56, 68, 47,
#        38, 71, 28, 22, 80, 46, 33, 49, 71, 63, 36, 86, 66, 88, 48, 70, 20,
#        72, 59, 27, 81, 52, 75, 72])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=75, count=17)
