# %% [markdown]
# # Welcome to Python Starter Notebook
# This is a simple notebook running inside VS Code.

# %%
# Simple Python code
x = 5
y = 10
print("Sum:", x + y)
print("Product:", x * y)
print("Difference:", y - x)

# %%
def greet(name):
    return "Hello, {name}!"

greet("World")
