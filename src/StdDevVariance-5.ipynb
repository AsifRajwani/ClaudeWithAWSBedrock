# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# Generate 10,000 random numbers from a normal distribution
# Parameters: mean=100.0, standard_deviation=20.0, size=10000
incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 20.01791375203863

# %%
incomes.var()
# Out:
# 400.7168709840573

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()
print ("Standard Deviation: ", incomes.std())
print ("Variance: ", incomes.var())
# Out:
# Standard Deviation:  50.68466832799359
# Variance:  2568.935603518717
